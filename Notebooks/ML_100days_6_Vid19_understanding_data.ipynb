# %%
import pandas as pd
df = pd.read_csv('matches.csv')
df.shape #understanding how big is the data
# Out:
# (636, 18)

# %%
df.sample(10) #"IMPORTANTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT": UNDERSTANDING THE OVERALL DATASET. BEST WAY OF GETTING AN OVERALL IDEA ON DATASET INSTEAD OF "HEAD"
# Out:
#       id  season            city        date                        team1  \
# 455  456    2013         Kolkata  2013-05-24             Rajasthan Royals
# 75    76    2008           Delhi  2008-04-30             Delhi Daredevils
# 528  529    2015   Visakhapatnam  2015-04-16          Sunrisers Hyderabad
# 186  187    2010       Ahmedabad  2010-03-20             Rajasthan Royals
# 580  581    2016         Kolkata  2016-04-13        Kolkata Knight Riders
# 237  238    2011           Delhi  2011-04-10             Delhi Daredevils
# 450  451    2013            Pune  2013-05-19                Pune Warriors
# 391  392    2013       Bangalore  2013-04-11        Kolkata Knight Riders
# 128  129    2009  Port Elizabeth  2009-04-26  Royal Challengers Bangalore
# 143  144    2009     East London  2009-05-04          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 455               Mumbai Indians             Rajasthan Royals           bat
# ...

# %%
df.info() #understanding the data types, memory used, and necessity to change data type i.e, 'date' here
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.isnull().sum() #understanding the need of filling or dropping columns (in general work). For example, here we may want to 'fill' city, winner, umpire 1, and umpire 2 columns because they lack most of the values which can be filled by injecting a common random number. On the other hand, we may want to 'drop' umpire3 column because filling such large numbers of data is exhaustively tiring
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
df.describe() #understanding mathematical look of the data
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.duplicated().sum() #understanding if there is any duplicate rows. If there is, WE MUST DROP THEM
# Out:
# 0

# %%
df.corr(numeric_only=True) #understanding 'correlation'. IMPORTANT: CORRELATION ONLY HAPPENS BETWEEN NUMERIC VALUES THUS 'numeric_only=True'
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets  \
# id              1.000000  0.471087    0.024281    -0.010263       -0.015510
# season          0.471087  1.000000    0.004170    -0.016815       -0.000708
# dl_applied      0.024281  0.004170    1.000000    -0.010893       -0.011640
# win_by_runs    -0.010263 -0.016815   -0.010893     1.000000       -0.565181
# win_by_wickets -0.015510 -0.000708   -0.011640    -0.565181        1.000000
# umpire3              NaN       NaN         NaN          NaN             NaN
#
#                 umpire3
# id                  NaN
# season              NaN
# dl_applied          NaN
# win_by_runs         NaN
# win_by_wickets      NaN
# umpire3             NaN

# %%
df.corr(numeric_only=True)['win_by_runs']
# Out:
# id               -0.010263
# season           -0.016815
# dl_applied       -0.010893
# win_by_runs       1.000000
# win_by_wickets   -0.565181
# umpire3                NaN
# Name: win_by_runs, dtype: float64
