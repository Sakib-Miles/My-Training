# %% [markdown]
# # **CSV file importing from URL**

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/refs/heads/main/day15%20-%20working%20with%20csv%20files/aug_train.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # **Importing TSV file**

# %%
pd.read_csv('file.tsv', sep='\t') #sep is initially set to ',', means that in comma-seperated values
# Out:
#           0    50  5  881250949
# 0         0   172  5  881250949
# 1         0   133  1  881250949
# 2       196   242  3  881250949
# 3       186   302  3  891717742
# 4        22   377  1  878887116
# ...     ...   ... ..        ...
# 99997   880   476  3  880175444
# 99998   716   204  5  879795543
# 99999   276  1090  1  874795795
# 100000   13   225  2  882399156
# 100001   12   203  3  879959583
#
# [100002 rows x 4 columns]

# %%
tsv = pd.read_csv('file.tsv', sep='\t', names=['serial','weight','iteration','imei']) #Python can't read column names for TSV files when only reading. So we need to assign them column names
tsv
# Out:
#         serial  weight  iteration       imei
# 0            0      50          5  881250949
# 1            0     172          5  881250949
# 2            0     133          1  881250949
# 3          196     242          3  881250949
# 4          186     302          3  891717742
# ...        ...     ...        ...        ...
# 99998      880     476          3  880175444
# 99999      716     204          5  879795543
# 100000     276    1090          1  874795795
# 100001      13     225          2  882399156
# 100002      12     203          3  879959583
#
# [100003 rows x 4 columns]

# %% [markdown]
# # **Index Column parameter**

# %%
pd.read_csv('aug_train.csv', index_col='enrollee_id') #preprocessing directly with reading data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-3bc0b29bf463> in <cell line: 1>()
# ----> 1 pd.read_csv('aug_train.csv', index_col='enrollee_id') #preprocessing directly with reading data
#
# ...

# %% [markdown]
# > *Now uploading a CSV file inside this Notebook*

# %%
pd.read_csv('matches.csv')
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
pd.read_csv('matches.csv', index_col='id')
# Out:
#      season       city        date                        team1  \
# id
# 1      2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2      2017       Pune  2017-04-06               Mumbai Indians
# 3      2017     Rajkot  2017-04-07                Gujarat Lions
# 4      2017     Indore  2017-04-08       Rising Pune Supergiant
# 5      2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..      ...        ...         ...                          ...
# 632    2016     Raipur  2016-05-22             Delhi Daredevils
# 633    2016  Bangalore  2016-05-24                Gujarat Lions
# 634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 635    2016      Delhi  2016-05-27                Gujarat Lions
# 636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# id
# 1    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %% [markdown]
# # **Header parameter**

# %% [markdown]
# > *Uploading another CSV file*

# %%
pd.read_csv('test.csv') #this is some kind of problem where our 'header row' wrongly stay with the values. We use 'header parameter' to solve this issue
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
# 3           3        33241   city_115                   0.789        NaN
# 4           4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# ...

# %%
pd.read_csv('test.csv', header=1)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %% [markdown]
# # **Use Columns parameter**

# %%
pd.read_csv('test.csv', usecols=['city','gender','enrollee_id']) #used for taking only necessary columns [NOTICEEEEEEEEEEEEEE: INTENTIONALLY CODED WRONG]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b80c557e0135> in <cell line: 1>()
# ----> 1 pd.read_csv('test.csv', usecols=['city','gender','enrollee_id']) #used for taking only necessary columns [NOTICEEEEEEEEEEEEEE: INTENTIONALLY CODED WRONG]
#
# ...

# %%
pd.read_csv('test.csv', header=1, usecols=['enrollee_id','city','gender']) #coded right
# Out:
#    enrollee_id      city gender
# 0        29725   city_40   Male
# 1        11561   city_21    NaN
# 2        33241  city_115    NaN
# 3          666  city_162   Male

# %% [markdown]
# # **nrows parameter**

# %%
pd.read_csv('matches.csv', nrows=100) #only takes 'given' number of rows from the file
# Out:
#      id  season        city        date                        team1  \
# 0     1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1     2    2017        Pune  2017-04-06               Mumbai Indians
# 2     3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3     4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4     5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# ..  ...     ...         ...         ...                          ...
# 95   96    2008      Mumbai  2008-05-14          Chennai Super Kings
# 96   97    2008  Chandigarh  2008-05-28              Kings XI Punjab
# 97   98    2008       Delhi  2008-05-15             Delhi Daredevils
# 98   99    2008      Mumbai  2008-05-16        Kolkata Knight Riders
# 99  100    2008       Delhi  2008-05-17             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # **Encoding parameter**

# %% [markdown]
# > **I ALREADY KNOW ABOUT IT LONG AGO**

# %% [markdown]
# # **Skip bad lines (lines with more values than supposed to)**

# %%
pd.read_csv('BX-Books.csv') #IMPORTANTTTTTTTTTTTTTTTTTT: If I encounter 'ParserError' then most likely something like this are underlaying in that given dataset
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-13-2f1a1449ef57> in <cell line: 1>()
# ----> 1 pd.read_csv('BX-Books.csv') #IMPORTANTTTTTTTTTTTTTTTTTT: If I encounter 'ParserError' then most likely something like this are underlaying in that given dataset
#
# ...

# %%
pd.read_csv('BX-Books.csv', sep=';', encoding='latin-1', on_bad_lines='warn') #IMPORTANTTTTTTTTTTTTTTTT: Warn About Bad Lines: If you want to be notified about the lines that are causing issues, you can set on_bad_lines to 'warn'. Less recommended
# Out:
# <ipython-input-17-bf9b9dfa0c4d>:1: ParserWarning: Skipping line 6451: expected 8 fields, saw 9
# Skipping line 43666: expected 8 fields, saw 10
# Skipping line 51750: expected 8 fields, saw 9
#
#   pd.read_csv('BX-Books.csv', sep=';', encoding='latin-1', on_bad_lines='warn') #IMPORTANTTTTTTTTTTTTTTTT: Warn About Bad Lines: If you want to be notified about the lines that are causing issues, you can set on_bad_lines to 'warn'. Less recommended
# <ipython-input-17-bf9b9dfa0c4d>:1: ParserWarning: Skipping line 92037: expected 8 fields, saw 9
# Skipping line 104318: expected 8 fields, saw 9
# Skipping line 121767: expected 8 fields, saw 9
#
#   pd.read_csv('BX-Books.csv', sep=';', encoding='latin-1', on_bad_lines='warn') #IMPORTANTTTTTTTTTTTTTTTT: Warn About Bad Lines: If you want to be notified about the lines that are causing issues, you can set on_bad_lines to 'warn'. Less recommended
# <ipython-input-17-bf9b9dfa0c4d>:1: ParserWarning: Skipping line 144057: expected 8 fields, saw 9
# ...

# %%
pd.read_csv('BX-Books.csv', sep=';', encoding='latin-1', on_bad_lines='skip') #IMPORTANTTTTTTTTTTTTTTTT: Skip Bad Lines: You can use the on_bad_lines parameter in the read_csv function to skip problematic lines. This is useful if you don’t need the data from those lines. More recommended
# Out:
# <ipython-input-7-2babceaa794d>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('BX-Books.csv', sep=';', encoding='latin-1', on_bad_lines='skip') #IMPORTANTTTTTTTTTTTTTTTT: Skip Bad Lines: You can use the on_bad_lines parameter in the read_csv function to skip problematic lines. This is useful if you don’t need the data from those lines. More recommended
#         0195153448                                Classical Mythology  \
# 0       0002005018                                       Clara Callan
# 1       0060973129                               Decision in Normandy
# 2       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3       0393045218                             The Mummies of Urumchi
# 4       0399135782                             The Kitchen God's Wife
# ...            ...                                                ...
# ...

# %% [markdown]
# > ***SEEMS LIKE PREPROCESSING!!***

# %% [markdown]
# # **Data Types parameter**

# %%
pd.read_csv('test.csv', header=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   0                       4 non-null      int64
#  1   enrollee_id             4 non-null      int64
#  2   city                    4 non-null      object
#  3   city_development_index  4 non-null      float64
#  4   gender                  2 non-null      object
#  5   relevent_experience     4 non-null      object
#  6   enrolled_university     3 non-null      object
#  7   education_level         4 non-null      object
#  8   major_discipline        4 non-null      object
#  9   experience              4 non-null      object
#  10  company_size            2 non-null      object
#  11  company_type            3 non-null      object
#  12  last_new_job            4 non-null      object
#  13  training_hours          4 non-null      int64
# ...

# %%
pd.read_csv('test.csv', header=1, dtype={'training_hours':float}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   0                       4 non-null      int64
#  1   enrollee_id             4 non-null      int64
#  2   city                    4 non-null      object
#  3   city_development_index  4 non-null      float64
#  4   gender                  2 non-null      object
#  5   relevent_experience     4 non-null      object
#  6   enrolled_university     3 non-null      object
#  7   education_level         4 non-null      object
#  8   major_discipline        4 non-null      object
#  9   experience              4 non-null      object
#  10  company_size            2 non-null      object
#  11  company_type            3 non-null      object
#  12  last_new_job            4 non-null      object
#  13  training_hours          4 non-null      float64
# ...

# %% [markdown]
# # **Handling dates**

# %%
pd.read_csv('matches.csv').info() #IMPORTANTTTTTTTTTTTTTTTTTTTTTTT: Notice that date column's data type is not in 'date data type'. It is Python's default feature to change the data type 'date' to 'object' when data being uploaded. SO, if I wanna do any manipulation involving date, I SIMPLY WON'T BE ABLE TO
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
pd.read_csv('matches.csv', parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    datetime64[ns]
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
# ...

# %% [markdown]
# # **Converter**

# %%
def rename(name):
  if name == "Kolkata Knight Riders":
    return "MI"
  else:
    return name

# %%
rename("Kolkata Knight Riders")
# Out:
# 'MI'

# %%
pd.read_csv('matches.csv', converters={'team2':rename})
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
rename("Sunrisers Hyderabad")
# Out:
# 'Sunrisers Hyderabad'

# %% [markdown]
# # **na_values parameter**

# %%
pd.read_csv('matches.csv')
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
pd.read_csv('matches.csv', na_values=['bat']) #'this parameter' used for if there are any null values other than 'NaN' i.e, '-', '%' etc. We can remove these null values from data using this parameter
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
pd.read_csv('matches.csv', na_values=['field'])
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
pd.read_csv('matches.csv', na_values=['bat', 'field'])
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner  toss_decision  \
# ...

# %% [markdown]
# # **Dividing huge datasets in chunks to work efficiently**

# %%
dfs = pd.read_csv('BX-Books.csv', sep=';', encoding='latin-1', on_bad_lines='skip', chunksize=5000)
dfs

# %%
for chunk in dfs: #LASTLY, if we code inside chunks, "THEN WE MUST CODE INSIDE UNDER THIS LOOP"
  print(chunk.shape)
# Out:
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (5000, 8)
# (1359, 8)

# %% [markdown]
# > ***READ FOLLOWING IMAGE. 'MOST MOST IMPORTANT'***

# %% [markdown]
# ![5646.PNG](data:image/png;base64,...)
